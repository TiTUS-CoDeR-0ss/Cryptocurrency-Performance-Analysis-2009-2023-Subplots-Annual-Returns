# %% [markdown]
# <a href="https://colab.research.google.com/github/TiTUS-CoDeR-0ss/Cryptocurrency-Performance-Analysis-2009-2023-Subplots-Annual-Returns/blob/main/Cryptocurrency_Performance_Analysis_2009_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Define cryptocurrencies
crypto_list = ["BTC-USD", "ETH-USD", "ADA-USD", "XRP-USD", "BNB-USD", "SOL-USD", "DOGE-USD"]

# Download price data
data = yf.download(crypto_list, start="2009-01-01", end="2023-12-31")

# Resample to monthly data (adjust as needed)
data = data.resample("M").mean()

# Calculate annual returns (opening and closing prices for each year)
yearly_data = data.resample("Y").agg({"Close": ["first", "last"]})
yearly_data.columns = ["Jan 1st", "Dec 31st"]

# Calculate annual change and percentage change
yearly_data["Change"] = yearly_data["Dec 31st"] - yearly_data["Jan 1st"]
yearly_data["Change %"] = (yearly_data["Change"] / yearly_data["Jan 1st"]) * 100

# Create subplots (3x2 grid for this example)
fig, axes = plt.subplots(3, 2, figsize=(15, 12))
count = 0

# Plot price data and calculate price at the beginning of each year (assuming $1 investment)
for i in range(3):
    for j in range(2):
        if count < len(crypto_list):
            # Price data subplot
            axes[i, j].plot(data.index, data[crypto_list[count]])
            axes[i, j].set_title(crypto_list[count] + " Price")
            axes[i, j].grid(True)

            # Calculate price at the beginning of each year (assuming $1 investment)
            yearly_data["Price at Jan 1st (" + crypto_list[count] + ")"] = data[crypto_list[count]].iloc[0] / yearly_data["Jan 1st"]

            # Plot price at the beginning of each year (optional)
            # axes[i, j].twinx()  # Uncomment to add a secondary y-axis for price
            # axes[i, j].plot(yearly_data.index, yearly_data["Price at Jan 1st (" + crypto_list[count] + ")"], color='red')

        count += 1

# Adjust layout and suptitle
fig.suptitle('Cryptocurrency Price Comparison (2009-2023) - Subplots & Annual Change')
plt.tight_layout()
plt.show()

# Print annual change table (consider exporting to CSV for detailed data)
print("Annual Change Summary (2009-2023):")
print(yearly_data[["Change %", "BTC-USD", "ETH-USD", "ADA-USD", "XRP-USD", "BNB-USD", "SOL-USD", "DOGE-USD"]].to_string())
# Out:
# [*********************100%%**********************]  7 of 7 completed
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-3454bb47f504> in <cell line: 15>()
#      13
#      14 # Calculate annual returns (opening and closing prices for each year)
# ---> 15 yearly_data = data.resample("Y").agg({"Close": ["first", "last"]})
#      16 yearly_data.columns = ["Jan 1st", "Dec 31st"]
#      17
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/resample.py in aggregate(self, func, *args, **kwargs)
#     327     )
#     328     def aggregate(self, func=None, *args, **kwargs):
# --> 329         result = ResamplerWindowApply(self, func, args=args, kwargs=kwargs).agg()
#     330         if result is None:
#     331             how = func
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in agg(self)
#     161
#     162         if is_dict_like(arg):
# --> 163             return self.agg_dict_like()
#     164         elif is_list_like(arg):
#     165             # we require a list, but not a 'str'
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in agg_dict_like(self)
#     401             selection = obj._selection
#     402
# --> 403         arg = self.normalize_dictlike_arg("agg", selected_obj, arg)
#     404
#     405         is_groupby = isinstance(obj, (DataFrameGroupBy, SeriesGroupBy))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in normalize_dictlike_arg(self, how, obj, func)
#     533             if len(cols) > 0:
#     534                 cols_sorted = list(safe_sort(list(cols)))
# --> 535                 raise KeyError(f"Column(s) {cols_sorted} do not exist")
#     536
#     537         aggregator_types = (list, tuple, dict)
#
# KeyError: "Column(s) ['Close'] do not exist"

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Define cryptocurrencies
crypto_list = ["BTC-USD", "ETH-USD", "ADA-USD", "XRP-USD", "BNB-USD", "SOL-USD", "DOGE-USD"]

# Download price data
data = yf.download(crypto_list, start="2009-01-01", end="2023-12-31")

# Resample to monthly data (adjust as needed)
data = data.resample("M").mean()

# Calculate annual returns (opening and closing prices for each year)
# Use 'Adj Close' instead of 'Close'
yearly_data = data.resample("Y").agg({"Adj Close": ["first", "last"]})
yearly_data.columns = ["Jan 1st", "Dec 31st"]

# Calculate annual change and percentage change
yearly_data["Change"] = yearly_data["Dec 31st"] - yearly_data["Jan 1st"]
yearly_data["Change %"] = (yearly_data["Change"] / yearly_data["Jan 1st"]) * 100

# ... (rest of your code remains the same)
# Out:
# [*********************100%%**********************]  7 of 7 completed
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-23bd41118a53> in <cell line: 16>()
#      14 # Calculate annual returns (opening and closing prices for each year)
#      15 # Use 'Adj Close' instead of 'Close'
# ---> 16 yearly_data = data.resample("Y").agg({"Adj Close": ["first", "last"]})
#      17 yearly_data.columns = ["Jan 1st", "Dec 31st"]
#      18
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/resample.py in aggregate(self, func, *args, **kwargs)
#     327     )
#     328     def aggregate(self, func=None, *args, **kwargs):
# --> 329         result = ResamplerWindowApply(self, func, args=args, kwargs=kwargs).agg()
#     330         if result is None:
#     331             how = func
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in agg(self)
#     161
#     162         if is_dict_like(arg):
# --> 163             return self.agg_dict_like()
#     164         elif is_list_like(arg):
#     165             # we require a list, but not a 'str'
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in agg_dict_like(self)
#     401             selection = obj._selection
#     402
# --> 403         arg = self.normalize_dictlike_arg("agg", selected_obj, arg)
#     404
#     405         is_groupby = isinstance(obj, (DataFrameGroupBy, SeriesGroupBy))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in normalize_dictlike_arg(self, how, obj, func)
#     533             if len(cols) > 0:
#     534                 cols_sorted = list(safe_sort(list(cols)))
# --> 535                 raise KeyError(f"Column(s) {cols_sorted} do not exist")
#     536
#     537         aggregator_types = (list, tuple, dict)
#
# KeyError: "Column(s) ['Adj Close'] do not exist"

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Define cryptocurrencies
crypto_list = ["BTC-USD", "ETH-USD", "ADA-USD", "XRP-USD", "BNB-USD", "SOL-USD", "DOGE-USD"]

# Download price data
data = yf.download(crypto_list, start="2009-01-01", end="2023-12-31")

# Resample to monthly data (adjust as needed)
data = data.resample("M").mean()

# Calculate annual returns (opening and closing prices for each year)
# Use 'Adj Close' (with space) instead of 'Close'
yearly_data = data.resample("Y").agg({"Adj Close": ["first", "last"]})
yearly_data.columns = ["Jan 1st", "Dec 31st"]

# Calculate annual change and percentage change
yearly_data["Change"] = yearly_data["Dec 31st"] - yearly_data["Jan 1st"]
yearly_data["Change %"] = (yearly_data["Change"] / yearly_data["Jan 1st"]) * 100

# ... (rest of your code remains the same)
# Out:
# [*********************100%%**********************]  7 of 7 completed
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-718d2f9abc13> in <cell line: 16>()
#      14 # Calculate annual returns (opening and closing prices for each year)
#      15 # Use 'Adj Close' (with space) instead of 'Close'
# ---> 16 yearly_data = data.resample("Y").agg({"Adj Close": ["first", "last"]})
#      17 yearly_data.columns = ["Jan 1st", "Dec 31st"]
#      18
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/resample.py in aggregate(self, func, *args, **kwargs)
#     327     )
#     328     def aggregate(self, func=None, *args, **kwargs):
# --> 329         result = ResamplerWindowApply(self, func, args=args, kwargs=kwargs).agg()
#     330         if result is None:
#     331             how = func
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in agg(self)
#     161
#     162         if is_dict_like(arg):
# --> 163             return self.agg_dict_like()
#     164         elif is_list_like(arg):
#     165             # we require a list, but not a 'str'
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in agg_dict_like(self)
#     401             selection = obj._selection
#     402
# --> 403         arg = self.normalize_dictlike_arg("agg", selected_obj, arg)
#     404
#     405         is_groupby = isinstance(obj, (DataFrameGroupBy, SeriesGroupBy))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in normalize_dictlike_arg(self, how, obj, func)
#     533             if len(cols) > 0:
#     534                 cols_sorted = list(safe_sort(list(cols)))
# --> 535                 raise KeyError(f"Column(s) {cols_sorted} do not exist")
#     536
#     537         aggregator_types = (list, tuple, dict)
#
# KeyError: "Column(s) ['Adj Close'] do not exist"

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Define cryptocurrencies
crypto_list = ["BTC-USD", "ETH-USD", "ADA-USD", "XRP-USD", "BNB-USD", "SOL-USD", "DOGE-USD"]

# Download price data
data = yf.download(crypto_list, start="2009-01-01", end="2023-12-31")

# Resample to monthly data (adjust as needed)
data = data.resample("M").mean()

# Calculate annual returns (opening and closing prices for each year)
# Use 'Adj Close' (without space) instead of 'Close'
yearly_data = data.resample("Y").agg({"Adj Close": ["first", "last"]})
yearly_data.columns = ["Jan 1st", "Dec 31st"]

# Calculate annual change and percentage change
yearly_data["Change"] = yearly_data["Dec 31st"] - yearly_data["Jan 1st"]
yearly_data["Change %"] = (yearly_data["Change"] / yearly_data["Jan 1st"]) * 100

# ... (rest of your code remains the same)
# Out:
# [*********************100%%**********************]  7 of 7 completed
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-e9dea8ec2bfe> in <cell line: 16>()
#      14 # Calculate annual returns (opening and closing prices for each year)
#      15 # Use 'Adj Close' (without space) instead of 'Close'
# ---> 16 yearly_data = data.resample("Y").agg({"Adj Close": ["first", "last"]})
#      17 yearly_data.columns = ["Jan 1st", "Dec 31st"]
#      18
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/resample.py in aggregate(self, func, *args, **kwargs)
#     327     )
#     328     def aggregate(self, func=None, *args, **kwargs):
# --> 329         result = ResamplerWindowApply(self, func, args=args, kwargs=kwargs).agg()
#     330         if result is None:
#     331             how = func
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in agg(self)
#     161
#     162         if is_dict_like(arg):
# --> 163             return self.agg_dict_like()
#     164         elif is_list_like(arg):
#     165             # we require a list, but not a 'str'
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in agg_dict_like(self)
#     401             selection = obj._selection
#     402
# --> 403         arg = self.normalize_dictlike_arg("agg", selected_obj, arg)
#     404
#     405         is_groupby = isinstance(obj, (DataFrameGroupBy, SeriesGroupBy))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in normalize_dictlike_arg(self, how, obj, func)
#     533             if len(cols) > 0:
#     534                 cols_sorted = list(safe_sort(list(cols)))
# --> 535                 raise KeyError(f"Column(s) {cols_sorted} do not exist")
#     536
#     537         aggregator_types = (list, tuple, dict)
#
# KeyError: "Column(s) ['Adj Close'] do not exist"

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Define cryptocurrencies
crypto_list = ["BTC-USD", "ETH-USD", "ADA-USD", "XRP-USD", "BNB-USD", "SOL-USD", "DOGE-USD"]

# Download price data
data = yf.download(crypto_list, start="2009-01-01", end="2023-12-31")

# Resample to monthly data (adjust as needed)
data = data.resample("M").mean()

# Check for existence of 'Adj Close' column (might not be available for all currencies)
if 'Adj Close' in data.columns:
    # Use 'Adj Close' for more accurate long-term comparisons (if available)
    yearly_data = data.resample("Y").agg({"Adj Close": ["first", "last"]})
else:
    # Use 'Close' if 'Adj Close' is not available
    print("WARNING: 'Adj Close' column not found. Using 'Close' instead.")
    yearly_data = data.resample("Y").agg({"Close": ["first", "last"]})

yearly_data.columns = ["Jan 1st", "Dec 31st"]

# Calculate annual change and percentage change
yearly_data["Change"] = yearly_data["Dec 31st"] - yearly_data["Jan 1st"]
yearly_data["Change %"] = (yearly_data["Change"] / yearly_data["Jan 1st"]) * 100

# Create subplots (3x2 grid for this example)
fig, axes = plt.subplots(3, 2, figsize=(15, 12))
count = 0

# Plot price data and calculate price at the beginning of each year (assuming $1 investment)
for i in range(3):
    for j in range(2):
        if count < len(crypto_list):
            # Price data subplot
            axes[i, j].plot(data.index, data[crypto_list[count]])
            axes[i, j].set_title(crypto_list[count] + " Price")
            axes[i, j].grid(True)

            # Calculate price at the beginning of each year (assuming $1 investment)
            yearly_data["Price at Jan 1st (" + crypto_list[count] + ")"] = data[crypto_list[count]].iloc[0] / yearly_data["Jan 1st"]

            # Plot price at the beginning of each year (optional)
            # axes[i, j].twinx()  # Uncomment to add a secondary y-axis for price
            # axes[i, j].plot(yearly_data.index, yearly_data["Price at Jan 1st (" + crypto_list[count] + ")"], color='red')

        count += 1

# Adjust layout and suptitle
fig.suptitle('Cryptocurrency Price Comparison (2009-2023) - Subplots & Annual Change')
plt.tight_layout()
plt.show()

# Print annual change table (consider exporting to CSV for detailed data)
print("Annual Change Summary (2009-2023):")
print(yearly_data[["Change %", "BTC-USD", "ETH-USD", "ADA-USD", "XRP-USD", "BNB-USD", "SOL-USD", "DOGE-USD"]].to_string())
# Out:
# [*********************100%%**********************]  7 of 7 completed
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-5e7715da9b24> in <cell line: 15>()
#      15 if 'Adj Close' in data.columns:
#      16     # Use 'Adj Close' for more accurate long-term comparisons (if available)
# ---> 17     yearly_data = data.resample("Y").agg({"Adj Close": ["first", "last"]})
#      18 else:
#      19     # Use 'Close' if 'Adj Close' is not available
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/resample.py in aggregate(self, func, *args, **kwargs)
#     327     )
#     328     def aggregate(self, func=None, *args, **kwargs):
# --> 329         result = ResamplerWindowApply(self, func, args=args, kwargs=kwargs).agg()
#     330         if result is None:
#     331             how = func
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in agg(self)
#     161
#     162         if is_dict_like(arg):
# --> 163             return self.agg_dict_like()
#     164         elif is_list_like(arg):
#     165             # we require a list, but not a 'str'
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in agg_dict_like(self)
#     401             selection = obj._selection
#     402
# --> 403         arg = self.normalize_dictlike_arg("agg", selected_obj, arg)
#     404
#     405         is_groupby = isinstance(obj, (DataFrameGroupBy, SeriesGroupBy))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in normalize_dictlike_arg(self, how, obj, func)
#     533             if len(cols) > 0:
#     534                 cols_sorted = list(safe_sort(list(cols)))
# --> 535                 raise KeyError(f"Column(s) {cols_sorted} do not exist")
#     536
#     537         aggregator_types = (list, tuple, dict)
#
# KeyError: "Column(s) ['Adj Close'] do not exist"

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Define cryptocurrencies
crypto_list = ["BTC-USD", "ETH-USD", "ADA-USD", "XRP-USD", "BNB-USD", "SOL-USD", "DOGE-USD"]

# Download price data
data = yf.download(crypto_list, start="2009-01-01", end="2023-12-31")

# Resample to monthly data (adjust as needed)
data = data.resample("M").mean()

# Handle potential missing 'Adj Close' column
available_columns = data.columns.tolist()
for currency in crypto_list:
    if f"{currency[:-3]} Adj Close" not in available_columns:
        print(f"WARNING: 'Adj Close' not found for {currency}. Using 'Close' instead.")

# Use the available closing price column (either 'Adj Close' or 'Close')
closing_column = "Adj Close" if "Adj Close" in data.columns else "Close"
yearly_data = data.resample("Y").agg({closing_column: ["first", "last"]})
yearly_data.columns = ["Jan 1st", "Dec 31st"]

# Calculate annual change and percentage change
yearly_data["Change"] = yearly_data["Dec 31st"] - yearly_data["Jan 1st"]
yearly_data["Change %"] = (yearly_data["Change"] / yearly_data["Jan 1st"]) * 100

# Create subplots (3x2 grid for this example)
fig, axes = plt.subplots(3, 2, figsize=(15, 12))
count = 0

# Plot price data and calculate price at the beginning of each year (assuming $1 investment)
for i in range(3):
    for j in range(2):
        if count < len(crypto_list):
            # Price data subplot
            axes[i, j].plot(data.index, data[crypto_list[count]])
            axes[i, j].set_title(crypto_list[count] + " Price")
            axes[i, j].grid(True)

            # Calculate price at the beginning of each year (assuming $1 investment)
            yearly_data["Price at Jan 1st (" + crypto_list[count] + ")"] = data[crypto_list[count]].iloc[0] / yearly_data["Jan 1st"]

            # Plot price at the beginning of each year (optional)
            # axes[i, j].twinx()  # Uncomment to add a secondary y-axis for price
            # axes[i, j].plot(yearly_data.index, yearly_data["Price at Jan 1st (" + crypto_list[count] + ")"], color='red')

        count += 1

# Adjust layout and suptitle
fig.suptitle('Cryptocurrency Price Comparison (2009-2023) - Subplots & Annual Change')
plt.tight_layout()
plt.show()

# Print annual change table (consider exporting to CSV for detailed data)
print("Annual Change Summary (2009-2023):")
print(yearly_data[["Change %", "BTC-USD", "ETH-USD", "ADA-USD", "XRP-USD", "BNB-USD", "SOL-USD", "DOGE-USD"]].to_string())
# Out:
# [*********************100%%**********************]  7 of 7 completed
# WARNING: 'Adj Close' not found for BTC-USD. Using 'Close' instead.
# WARNING: 'Adj Close' not found for ETH-USD. Using 'Close' instead.
# WARNING: 'Adj Close' not found for ADA-USD. Using 'Close' instead.
# WARNING: 'Adj Close' not found for XRP-USD. Using 'Close' instead.
# WARNING: 'Adj Close' not found for BNB-USD. Using 'Close' instead.
# WARNING: 'Adj Close' not found for SOL-USD. Using 'Close' instead.
# WARNING: 'Adj Close' not found for DOGE-USD. Using 'Close' instead.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-7ff8bf16e21b> in <cell line: 22>()
#      20 # Use the available closing price column (either 'Adj Close' or 'Close')
#      21 closing_column = "Adj Close" if "Adj Close" in data.columns else "Close"
# ---> 22 yearly_data = data.resample("Y").agg({closing_column: ["first", "last"]})
#      23 yearly_data.columns = ["Jan 1st", "Dec 31st"]
#      24
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/resample.py in aggregate(self, func, *args, **kwargs)
#     327     )
#     328     def aggregate(self, func=None, *args, **kwargs):
# --> 329         result = ResamplerWindowApply(self, func, args=args, kwargs=kwargs).agg()
#     330         if result is None:
#     331             how = func
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in agg(self)
#     161
#     162         if is_dict_like(arg):
# --> 163             return self.agg_dict_like()
#     164         elif is_list_like(arg):
#     165             # we require a list, but not a 'str'
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in agg_dict_like(self)
#     401             selection = obj._selection
#     402
# --> 403         arg = self.normalize_dictlike_arg("agg", selected_obj, arg)
#     404
#     405         is_groupby = isinstance(obj, (DataFrameGroupBy, SeriesGroupBy))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in normalize_dictlike_arg(self, how, obj, func)
#     533             if len(cols) > 0:
#     534                 cols_sorted = list(safe_sort(list(cols)))
# --> 535                 raise KeyError(f"Column(s) {cols_sorted} do not exist")
#     536
#     537         aggregator_types = (list, tuple, dict)
#
# KeyError: "Column(s) ['Adj Close'] do not exist"

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Define cryptocurrencies
crypto_list = ["BTC-USD", "ETH-USD", "ADA-USD", "XRP-USD", "BNB-USD", "SOL-USD", "DOGE-USD"]

# Download price data
data = yf.download(crypto_list, start="2009-01-01", end="2023-12-31")

# Resample to monthly data (adjust as needed)
data = data.resample("M").mean()

# Handle potential missing 'Adj Close' column
yearly_data_list = []
for currency in crypto_list:
    closing_column = ("Adj Close", currency) if ("Adj Close", currency) in data.columns else ("Close", currency)
    # Use the available closing price column (either 'Adj Close' or 'Close')
    yearly_data_currency = data.resample("Y").agg({closing_column: ["first", "last"]})
    yearly_data_currency.columns = [f"{currency} Jan 1st", f"{currency} Dec 31st"]
    yearly_data_list.append(yearly_data_currency)
    if closing_column[0] == "Close":
        print(f"WARNING: 'Adj Close' not found for {currency}. Using 'Close' instead.")

# Combine the yearly data for all currencies
yearly_data = pd.concat(yearly_data_list, axis=1)

# Calculate annual change and percentage change for each currency
for currency in crypto_list:
    yearly_data[f"{currency} Change"] = yearly_data[f"{currency} Dec 31st"] - yearly_data[f"{currency} Jan 1st"]
    yearly_data[f"{currency} Change %"] = (yearly_data[f"{currency} Change"] / yearly_data[f"{currency} Jan 1st"]) * 100

# Create subplots (3x2 grid for this example)
fig, axes = plt.subplots(3, 2, figsize=(15, 12))
count = 0

# Plot price data and calculate price at the beginning of each year (assuming $1 investment)
for i in range(3):
    for j in range(2):
        if count < len(crypto_list):
            currency = crypto_list[count]
            # Price data subplot
            axes[i, j].plot(data.index, data[("Close", currency)]) # Use "Close" here as it's always available
            axes[i, j].set_title(currency + " Price")
            axes[i, j].grid(True)

            # Calculate price at the beginning of each year (assuming $1 investment)
            yearly_data[f"Price at Jan 1st ({currency})"] = data[("Close", currency)].iloc[0] / yearly_data[f"{currency} Jan 1st"]

            # Plot price at the beginning of each year (optional)
            # axes[i, j].twinx()  # Uncomment to add a secondary y-axis for price
            # axes[i, j].plot(yearly_data.index, yearly_data[f"Price at Jan 1st ({currency})"], color='red')

        count += 1

# Adjust layout and suptitle
fig.suptitle('Cryptocurrency Price Comparison (2009-2023) - Subplots & Annual Change')
plt.tight_layout()
plt.show()

# Print annual change table (consider exporting to CSV for detailed data)
print("Annual Change Summary (2009-2023):")
columns_to_print = [f"{currency} Change %" for currency in crypto_list]
print(yearly_data[columns_to_print].to_string())
# Out:
# [*********************100%%**********************]  7 of 7 completed
# Annual Change Summary (2009-2023):
#             BTC-USD Change %  ETH-USD Change %  ADA-USD Change %  XRP-USD Change %  BNB-USD Change %  SOL-USD Change %  DOGE-USD Change %
# Date
# 2014-12-31        -16.187967               NaN               NaN               NaN               NaN               NaN                NaN
# 2015-12-31         70.616690               NaN               NaN               NaN               NaN               NaN                NaN
# 2016-12-31        101.550802               NaN               NaN               NaN               NaN               NaN                NaN
# 2017-12-31       1571.658198         68.594992        682.565958        251.804221        177.694674               NaN         231.859719
# 2018-12-31        -71.590907        -90.123817        -95.148666        -81.849561        -64.483212               NaN         -75.775140
# 2019-12-31         96.782517          7.698158        -18.553455        -37.653973        126.480433               NaN          -0.223791
# 2020-12-31        162.038721        296.558358        277.840578        114.042944         93.178843        139.409759          62.944778
# 2021-12-31         41.717120        236.360337        335.114015        200.340296       1221.792504       5578.302503        1312.051532
# 2022-12-31        -58.774542        -59.500963        -76.656138        -48.769309        -40.362236        -90.403852         -45.588296
# 2023-12-31        110.147042         54.135554         67.154337         64.494513        -10.410412        312.647431          14.543661
